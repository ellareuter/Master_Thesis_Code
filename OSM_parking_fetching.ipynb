# %%
import overpy
import pandas as pd
import time
import geopandas as gpd
import osmnx as ox
from shapely.geometry import Point, Polygon, LineString
from geopandas import GeoDataFrame

# %%
# Configure osmnx to not use cache
ox.config(use_cache=False)
# Out:
# /var/folders/3f/3mffjgc50tdc2j3m2fqnxfxc0000gn/T/ipykernel_8456/3057731840.py:2: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   ox.config(use_cache=False)

# %%
# Function to create bounding boxes
def generate_bboxes(south, west, north, east, lat_step=1.0, lon_step=1.0):
    """Generate non-overlapping bounding boxes given a larger bounding box."""
    assert south < north, "Invalid latitude range"
    assert west < east, "Invalid longitude range"
    
    lat_ranges = [south + i*lat_step for i in range(int((north-south)/lat_step) + 1)]
    lon_ranges = [west + i*lon_step for i in range(int((east-west)/lon_step) + 1)]
    
    bboxes = [(lat_ranges[i], lon_ranges[j], lat_ranges[i+1], lon_ranges[j+1]) 
              for i in range(len(lat_ranges)-1) 
              for j in range(len(lon_ranges)-1)]
    
    return bboxes

# %%
# Function to create overlapping bounding boxes
def add_overlap_to_bboxes(bboxes, lat_overlap, lon_overlap, max_north, max_east, min_south, min_west):
    """Add overlap to bounding boxes without exceeding specified max and min lat and lon."""
    return [
        (max(south-lat_overlap, min_south), 
         max(west-lon_overlap, min_west),
         min(north+lat_overlap, max_north), 
         min(east+lon_overlap, max_east)) 
        for south, west, north, east in bboxes
    ]

# %%
# Function to fetch parking data for bbox
def fetch_parking_data_for_bbox(bbox, max_retries=3):
    """Query parking data for a given bounding box."""
    api = overpy.Overpass()
    bbox_str = ",".join(map(str, bbox))
    retries = 0
    
    while retries < max_retries:
        try:
            query = f"""
            [out:json];
            (
              node["amenity"="parking"]["access"~"public|customers|permissive|yes"]({bbox_str});
              way["amenity"="parking"]["access"~"public|customers|permissive|yes"]({bbox_str});
              relation["amenity"="parking"]["access"~"public|customers|permissive|yes"]({bbox_str});
              node["amenity"="parking"]["access"!~".*"]({bbox_str});
              way["amenity"="parking"]["access"!~".*"]({bbox_str});
              relation["amenity"="parking"]["access"!~".*"]({bbox_str});
            );
            out body;
            >;
            out skel qt;
            """
            result = api.query(query)
            return result
        except (overpy.exception.OverpassRuntimeError, Exception):
            retries += 1
            print(f"Error for bbox {bbox}. Retrying {retries}/{max_retries}...")
            time.sleep(10)

    print(f"Failed to fetch data for bbox {bbox} after {max_retries} retries.")
    return None

# %%
def extract_vertices_from_entity(entity):
    """Extract vertices for an entity."""
    return [(m.lon, m.lat) for m in entity.nodes if hasattr(m, "lat") and hasattr(m, "lon")]

# %%
def extract_way_geometry(way):
    """Extract geometry for a Way."""
    verts = extract_vertices_from_entity(way)
    
    # If the first and last vertex are the same, it's a polygon
    if verts[0] == verts[-1]:
        return Polygon(verts)
    # Otherwise, it's a line string
    else:
        return LineString(verts)

# %%
def extract_relation_geometry(relation):
    """Extract geometry for a Relation."""
    outer_polys = []

    for member in relation.members:
        if isinstance(member, overpy.Way) and member.role == "outer":
            verts = extract_vertices_from_entity(member)
            outer_polys.append(verts)

    # If there's only one outer boundary, it's a Polygon
    if len(outer_polys) == 1:
        return Polygon(outer_polys[0])
    # If there are multiple outer boundaries, it's a MultiPolygon
    elif len(outer_polys) > 1:
        polys = [Polygon(outer) for outer in outer_polys]
        return MultiPolygon(polys)

    return None

# %%
def process_result(result):
    """Process OSM result to extract parking data."""
    
    # Process nodes
    for node in result.nodes:
        add_to_data(node, node.lat, node.lon, geom=Point(node.lon, node.lat))

    # Process ways
    for way in result.ways:
        geom = extract_way_geometry(way)
        add_to_data(way, None, None, geom=geom)

    # Process relations
    for relation in result.relations:
        geom = extract_relation_geometry(relation)
        if geom:
            add_to_data(relation, None, None, geom=geom)

# %%
TAGS_LIST = [
    'name', 'parking', 'capacity', 'capacity:charging', 'fee',
    'supervised', 'surface', 'maxstay', 'opening_hours', 'operator',
    'website', 'zone', 'capacity:disabled', 'capacity:parent',
    'ref', 'park_ride'
]

# %%
def add_to_data(element, lat=None, lon=None, geom=None):
    """Extract parking data from an OSM element and append to df_data list."""
    # Check the geometry type to extract vertices accordingly
    if isinstance(geom, Point):
        vertices = [(geom.x, geom.y)]
    elif isinstance(geom, LineString):
        vertices = list(geom.coords)
    elif geom and hasattr(geom, 'exterior'):  # for Polygon
        vertices = list(geom.exterior.coords)
    else:
        vertices = None

    data_dict = {
        "ID": element.id,
        "Latitude": lat,
        "Longitude": lon,
        "Geometry": geom,
        "Vertices": vertices
    }

    for tag in TAGS_LIST:
        data_dict[tag.capitalize()] = element.tags.get(tag, 'Unknown')

    df_data.append(data_dict)

# %%
# Fetching Germany boundary and defining its bounding box
germany_osm = ox.geocode_to_gdf("Germany")
GERMANY_BBOX_DF = germany_osm.bounds.iloc[0]
GERMANY_BBOX = (GERMANY_BBOX_DF['miny'], GERMANY_BBOX_DF['minx'], GERMANY_BBOX_DF['maxy'], GERMANY_BBOX_DF['maxx'])

# %%
bboxes = generate_bboxes(*GERMANY_BBOX, lat_step=0.5, lon_step=0.5)
overlapping_bboxes = add_overlap_to_bboxes(bboxes, 0.05, 0.05, 
                                           GERMANY_BBOX[2], GERMANY_BBOX[3], 
                                           GERMANY_BBOX[0], GERMANY_BBOX[1])

# %%
# Fetching and processing data
all_results = []
df_data = []
for index, bbox in enumerate(overlapping_bboxes, 1):
    print(f"Fetching data for bbox {index}/{len(overlapping_bboxes)}: {bbox}")
    result = fetch_parking_data_for_bbox(bbox)
    if result:
        process_result(result)
        all_results.append(result)
# Out:
# Fetching data for bbox 1/270: (47.2701114, 5.8663153, 47.820111399999995, 6.4163153)
# Fetching data for bbox 2/270: (47.2701114, 6.3163153, 47.820111399999995, 6.9163153)
# Fetching data for bbox 3/270: (47.2701114, 6.8163153, 47.820111399999995, 7.4163153)
# 7   [(6.0077722, 47.3269559)]           Unknown  Unknown  Unknown
# 8   [(6.0122461, 47.3293047)]           Unknown  Unknown  Unknown
# 9   [(6.0188444, 47.3303519)]           Unknown  Unknown  Unknown
# 10  [(6.0525229, 47.5375324)]           Unknown  Unknown  Unknown
# 11  [(6.2330563, 47.2983272)]           Unknown  surface  Unknown
# 12  [(6.0754205, 47.2815991)]           Unknown  Unknown  Unknown
# 13  [(6.0755687, 47.2820488)]           Unknown  Unknown  Unknown
# 14  [(6.0771251, 47.2823482)]           Unknown  Unknown  Unknown
# 15  [(6.0775857, 47.2828269)]           Unknown  surface  Unknown
# 16  [(6.0769726, 47.2832384)]   Salle des Fêtes  Unknown       41
# 17  [(6.3767741, 47.4219568)]           Unknown  Unknown  Unknown
# 18  [(6.3588956, 47.3409214)]           Unknown  Unknown  Unknown
# 19  [(6.3594528, 47.3413702)]           Unknown  Unknown  Unknown
#
#    Capacity:charging      Fee  ...  Surface  Maxstay Opening_hours Operator
# 0            Unknown       no  ...  Unknown  Unknown       Unknown  Unknown  \
# 1            Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 2            Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 3            Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 4            Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 5            Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 6            Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 7            Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 8            Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 9            Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 10           Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 11           Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 12           Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 13           Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 14           Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 15           Unknown       no  ...  Unknown  Unknown       Unknown  Unknown
# 16           Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 17           Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 18           Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
# 19           Unknown  Unknown  ...  Unknown  Unknown       Unknown  Unknown
#
#     Website     Zone Capacity:disabled Capacity:parent      Ref Park_ride
# 0   Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 1   Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 2   Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 3   Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 4   Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 5   Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 6   Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 7   Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 8   Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 9   Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 10  Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 11  Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 12  Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 13  Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 14  Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 15  Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 16  Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 17  Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 18  Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
# 19  Unknown  Unknown           Unknown         Unknown  Unknown   Unknown
#
# [20 rows x 21 columns]

# %%
len(df)
# Out:
# 6799364

# %%
# Remove duplicates 
df_cleaned = df.drop_duplicates(subset='ID', keep='first')
print(len(df_cleaned))
# Out:
# 4831949

# %%
# Convert the dataframe to a GeoDataFrame with appropriate geometry
gdf = gpd.GeoDataFrame(df_cleaned, geometry='Geometry', crs="EPSG:4326")

# %%
parking_in_germany = gpd.sjoin(gdf, germany_osm, how="inner", predicate="within")

# Drop the unnecessary index and columns introduced from germany_osm after join
original_columns = gdf.columns
parking_in_germany = parking_in_germany[original_columns]

# %%
len(parking_in_germany)
# Out:
# 3689321

# %%
parking_in_germany.head(20)
# Out:
#               ID    Latitude  Longitude                  Geometry
# 65248    9323857  47.7148176  7.6537833  POINT (7.65378 47.71482)  \
# 65249   21307663  47.7893012  7.5377884  POINT (7.53779 47.78930)
# 65250   27124796  47.6300774  7.5839347  POINT (7.58393 47.63008)
# 65251   27358093  47.5905453  7.5929529  POINT (7.59295 47.59055)
# 65252   35108095  47.5806549  7.7864517  POINT (7.78645 47.58065)
# 65253   35262861  47.7317643  7.5582767  POINT (7.55828 47.73176)
# 65254   35334594  47.7280664  7.5936679  POINT (7.59367 47.72807)
# 65255   35360209  47.7161753  7.5586050  POINT (7.55861 47.71618)
# 65256   36691854  47.6578978  7.6042919  POINT (7.60429 47.65790)
# 65257   36694168  47.6125462  7.5921697  POINT (7.59217 47.61255)
# 65261  247081452  47.6313361  7.5872625  POINT (7.58726 47.63134)
# 65262  247265054  47.7067979  7.5255324  POINT (7.52553 47.70680)
# 65264  252390371  47.6366323  7.6306300  POINT (7.63063 47.63663)
# 65266  252503628  47.6264214  7.8116116  POINT (7.81161 47.62642)
# 65267  252637514  47.5935513  7.8031784  POINT (7.80318 47.59355)
# 65268  252661273  47.6118167  7.7270070  POINT (7.72701 47.61182)
# 65269  254209622  47.6008246  7.6786072  POINT (7.67861 47.60082)
# 65270  254863678  47.6409832  7.7264141  POINT (7.72641 47.64098)
# 65271  255598584  47.8088298  7.6221308  POINT (7.62213 47.80883)
# 65272  257610820  47.6601504  7.5630806  POINT (7.56308 47.66015)
#
#                         Vertices                     Name       Parking
# 65248  [(7.6537833, 47.7148176)]                  Unknown       surface  \
# 65249  [(7.5377884, 47.7893012)]                  Unknown          lane
# 65250  [(7.5839347, 47.6300774)]                  Unknown       surface
# 65251  [(7.5929529, 47.5905453)]                  Unknown  multi-storey
# 65252  [(7.7864517, 47.5806549)]                  Unknown       surface
# 65253  [(7.5582767, 47.7317643)]  Parkplatz an der Kirche       surface
# 65254  [(7.5936679, 47.7280664)]                  Unknown       Unknown
# 65255   [(7.558605, 47.7161753)]                  Unknown       Unknown
# 65256  [(7.6042919, 47.6578978)]                  Unknown       surface
# 65257  [(7.5921697, 47.6125462)]                  Unknown          lane
# 65261  [(7.5872625, 47.6313361)]                  Unknown       Unknown
# 65262  [(7.5255324, 47.7067979)]                 Rheinaue       surface
# 65264    [(7.63063, 47.6366323)]                  Unknown       surface
# 65266  [(7.8116116, 47.6264214)]                  Unknown       surface
# 65267  [(7.8031784, 47.5935513)]                  Unknown       surface
# 65268   [(7.727007, 47.6118167)]                  Unknown       Unknown
# 65269  [(7.6786072, 47.6008246)]                  Unknown       surface
# 65270  [(7.7264141, 47.6409832)]              Tennishalle       Unknown
# 65271  [(7.6221308, 47.8088298)]                  Unknown       surface
# 65272  [(7.5630806, 47.6601504)]             Schützenhaus       Unknown
#
#       Capacity Capacity:charging      Fee  ...  Surface  Maxstay
# 65248  Unknown           Unknown  Unknown  ...  Unknown  Unknown  \
# 65249  Unknown           Unknown       no  ...  Unknown  Unknown
# 65250  Unknown           Unknown       no  ...  Unknown  Unknown
# 65251  Unknown           Unknown       no  ...  Unknown  Unknown
# 65252  Unknown           Unknown  Unknown  ...  Unknown  Unknown
# 65253       25           Unknown       no  ...  Unknown  Unknown
# 65254  Unknown           Unknown  Unknown  ...  Unknown  Unknown
# 65255  Unknown           Unknown  Unknown  ...  Unknown  Unknown
# 65256  Unknown           Unknown  Unknown  ...  Unknown  Unknown
# 65257  Unknown           Unknown  Unknown  ...  Unknown  Unknown
# 65261  Unknown           Unknown  Unknown  ...  Unknown  Unknown
# 65262  Unknown           Unknown       no  ...  Unknown  Unknown
# 65264  Unknown           Unknown  Unknown  ...  Unknown  Unknown
# 65266  Unknown           Unknown       no  ...  Unknown  Unknown
# 65267  Unknown           Unknown  Unknown  ...  Unknown  Unknown
# 65268  Unknown           Unknown  Unknown  ...  Unknown  Unknown
# 65269  Unknown           Unknown       no  ...  Unknown  Unknown
# 65270  Unknown           Unknown  Unknown  ...  Unknown  Unknown
# 65271  Unknown           Unknown  Unknown  ...  Unknown  Unknown
# 65272  Unknown           Unknown  Unknown  ...  Unknown  Unknown
#
#       Opening_hours Operator  Website     Zone Capacity:disabled
# 65248       Unknown  Unknown  Unknown  Unknown           Unknown  \
# 65249       Unknown  Unknown  Unknown  Unknown           Unknown
# 65250       Unknown  Unknown  Unknown  Unknown           Unknown
# 65251       Unknown  Unknown  Unknown  Unknown           Unknown
# 65252       Unknown  Unknown  Unknown  Unknown           Unknown
# 65253       Unknown  Unknown  Unknown  Unknown           Unknown
# 65254       Unknown  Unknown  Unknown  Unknown           Unknown
# 65255       Unknown  Unknown  Unknown  Unknown           Unknown
# 65256       Unknown  Unknown  Unknown  Unknown           Unknown
# 65257       Unknown  Unknown  Unknown  Unknown           Unknown
# 65261       Unknown  Unknown  Unknown  Unknown           Unknown
# 65262       Unknown  Unknown  Unknown  Unknown           Unknown
# 65264       Unknown  Unknown  Unknown  Unknown           Unknown
# 65266       Unknown  Unknown  Unknown  Unknown           Unknown
# 65267       Unknown  Unknown  Unknown  Unknown           Unknown
# 65268       Unknown  Unknown  Unknown  Unknown           Unknown
# 65269       Unknown  Unknown  Unknown  Unknown           Unknown
# 65270       Unknown  Unknown  Unknown  Unknown           Unknown
# 65271       Unknown  Unknown  Unknown  Unknown           Unknown
# 65272       Unknown  Unknown  Unknown  Unknown           Unknown
#
#       Capacity:parent      Ref Park_ride
# 65248         Unknown  Unknown   Unknown
# 65249         Unknown  Unknown   Unknown
# 65250         Unknown  Unknown   Unknown
# 65251         Unknown  Unknown   Unknown
# 65252         Unknown  Unknown   Unknown
# 65253         Unknown  Unknown   Unknown
# 65254         Unknown  Unknown   Unknown
# 65255         Unknown  Unknown   Unknown
# 65256         Unknown  Unknown   Unknown
# 65257         Unknown  Unknown   Unknown
# 65261         Unknown  Unknown   Unknown
# 65262         Unknown  Unknown   Unknown
# 65264         Unknown  Unknown   Unknown
# 65266         Unknown  Unknown   Unknown
# 65267         Unknown  Unknown   Unknown
# 65268         Unknown  Unknown   Unknown
# 65269         Unknown  Unknown   Unknown
# 65270         Unknown  Unknown   Unknown
# 65271         Unknown  Unknown   Unknown
# 65272         Unknown  Unknown   Unknown
#
# [20 rows x 21 columns]

# %%
# Convert the GeoDataFrame to the desired CRS and add areas in m2 to the polygons
parking_in_germany = parking_in_germany.to_crs("EPSG:25832")
parking_in_germany["Area_m2"] = parking_in_germany["Geometry"].area

# %%
# Save as CSV
csv_path = "~/Desktop/Masterarbeit/data/osm_parking_data_fetching.csv"
parking_in_germany.to_csv(csv_path, index=False)

# %%
# Convert Latitude and Longitude to float
parking_in_germany['Latitude'] = parking_in_germany['Latitude'].astype(float)
parking_in_germany['Longitude'] = parking_in_germany['Longitude'].astype(float)

# %%
# Convert Vertices to string
parking_in_germany['Vertices'] = parking_in_germany['Longitude'].astype(str)

# %%
# Select only necessary columns
subset_gdf = parking_in_germany[['ID', 'Latitude', 'Longitude', 'Geometry', 'Vertices']]

# %%
# Save to GPKG
file_path = "~/Desktop/Masterarbeit/osm_parking_areas_in_germany.gpkg"
subset_gdf.to_file(file_path, driver='GPKG')
